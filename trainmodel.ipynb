# %%
from keras.utils import to_categorical
from keras_preprocessing.image import load_img
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
import os
import pandas as pd
import numpy as np

# %%
TRAIN_DIR = 'images/train'
TEST_DIR = 'images/test'

# %%
def createdataframe(dir):
    image_paths = []
    labels = []
    for label in os.listdir(dir):
        for imagename in os.listdir(os.path.join(dir,label)):
            image_paths.append(os.path.join(dir,label,imagename))
            labels.append(label)
        print(label, "completed")
    return image_paths, labels

# %%
train = pd.DataFrame()
train['image'], train['label'] = createdataframe(TRAIN_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(train)
# Out:
#                                 image     label
# 0            images/train\angry\0.jpg     angry
# 1            images/train\angry\1.jpg     angry
# 2           images/train\angry\10.jpg     angry
# 3        images/train\angry\10002.jpg     angry
# 4        images/train\angry\10016.jpg     angry
# ...                               ...       ...
# 28816  images/train\surprise\9969.jpg  surprise
# 28817  images/train\surprise\9985.jpg  surprise
# 28818  images/train\surprise\9990.jpg  surprise
# 28819  images/train\surprise\9992.jpg  surprise
# 28820  images/train\surprise\9996.jpg  surprise
#
# [28821 rows x 2 columns]

# %%
test = pd.DataFrame()
test['image'], test['label'] = createdataframe(TEST_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(test)
# Out:
#                               image     label
# 0       images/test\angry\10052.jpg     angry
# 1       images/test\angry\10065.jpg     angry
# 2       images/test\angry\10079.jpg     angry
# 3       images/test\angry\10095.jpg     angry
# 4       images/test\angry\10121.jpg     angry
# ...                             ...       ...
# 7061  images/test\surprise\9806.jpg  surprise
# 7062  images/test\surprise\9830.jpg  surprise
# 7063  images/test\surprise\9853.jpg  surprise
# 7064  images/test\surprise\9878.jpg  surprise
# 7065   images/test\surprise\993.jpg  surprise
#
# [7066 rows x 2 columns]

# %%
from tqdm.notebook import tqdm

# %%
def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(image,grayscale = True)
        img = np.array(img)
        features.append(img)
    features = np.array(features)
    features = features.reshape(len(features),48,48,1)
    return features

# %%
train_features = extract_features(train['image'])
# Out:
#   0%|          | 0/28821 [00:00<?, ?it/s]
# C:\Users\Anshimsa\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_preprocessing\image\utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
test_features = extract_features(test['image'])
# Out:
#   0%|          | 0/7066 [00:00<?, ?it/s]

# %%
x_train = train_features/255.0
x_test = test_features/255.0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit(train['label'])
# Out:
# LabelEncoder()

# %%
y_train = le.transform(train['label'])
y_test = le.transform(test['label'])

# %%
y_train = to_categorical(y_train, num_classes = 7)
y_test = to_categorical(y_test, num_classes = 7)

# %%
from keras.layers import Input

# %%
model = Sequential()
model.add(Input(shape=(48, 48, 1)))
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(7, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x=x_train, y=y_train, batch_size = 128, epochs = 100, validation_data = (x_test, y_test))
# Out:
# Epoch 1/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 342s 2s/step - accuracy: 0.5110 - loss: 1.2870 - val_accuracy: 0.5430 - val_loss: 1.2032
# Epoch 2/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 298s 1s/step - accuracy: 0.5150 - loss: 1.2666 - val_accuracy: 0.5528 - val_loss: 1.1759
# Epoch 3/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 289s 1s/step - accuracy: 0.5249 - loss: 1.2506 - val_accuracy: 0.5617 - val_loss: 1.1589
# Epoch 4/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 287s 1s/step - accuracy: 0.5365 - loss: 1.2166 - val_accuracy: 0.5713 - val_loss: 1.1467
# Epoch 5/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 287s 1s/step - accuracy: 0.5311 - loss: 1.2224 - val_accuracy: 0.5756 - val_loss: 1.1370
# Epoch 6/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 322s 1s/step - accuracy: 0.5444 - loss: 1.1997 - val_accuracy: 0.5788 - val_loss: 1.1184
# Epoch 7/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 283s 1s/step - accuracy: 0.5481 - loss: 1.1783 - val_accuracy: 0.5763 - val_loss: 1.1265
# Epoch 8/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 274s 1s/step - accuracy: 0.5542 - loss: 1.1697 - val_accuracy: 0.5814 - val_loss: 1.1108
# Epoch 9/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 288s 1s/step - accuracy: 0.5567 - loss: 1.1693 - val_accuracy: 0.5780 - val_loss: 1.1099
# Epoch 10/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 321s 1s/step - accuracy: 0.5628 - loss: 1.1663 - val_accuracy: 0.5852 - val_loss: 1.1034
# Epoch 11/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 294s 1s/step - accuracy: 0.5593 - loss: 1.1489 - val_accuracy: 0.5863 - val_loss: 1.0901
# Epoch 12/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - accuracy: 0.5707 - loss: 1.1449 - val_accuracy: 0.5904 - val_loss: 1.0959
# Epoch 13/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - accuracy: 0.5708 - loss: 1.1305 - val_accuracy: 0.5918 - val_loss: 1.0918
# Epoch 14/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.5784 - loss: 1.1182 - val_accuracy: 0.5909 - val_loss: 1.0970
# Epoch 15/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.5809 - loss: 1.1070 - val_accuracy: 0.5918 - val_loss: 1.0789
# Epoch 16/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.5824 - loss: 1.0965 - val_accuracy: 0.5998 - val_loss: 1.0731
# Epoch 17/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - accuracy: 0.5843 - loss: 1.0879 - val_accuracy: 0.5967 - val_loss: 1.0738
# Epoch 18/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.5900 - loss: 1.0926 - val_accuracy: 0.5991 - val_loss: 1.0723
# Epoch 19/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.5858 - loss: 1.0839 - val_accuracy: 0.5998 - val_loss: 1.0764
# Epoch 20/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 322s 1s/step - accuracy: 0.5894 - loss: 1.0820 - val_accuracy: 0.6010 - val_loss: 1.0663
# Epoch 21/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 323s 1s/step - accuracy: 0.5964 - loss: 1.0684 - val_accuracy: 0.6104 - val_loss: 1.0531
# Epoch 22/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 271s 1s/step - accuracy: 0.5980 - loss: 1.0542 - val_accuracy: 0.6076 - val_loss: 1.0654
# Epoch 23/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.6035 - loss: 1.0507 - val_accuracy: 0.6084 - val_loss: 1.0509
# Epoch 24/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.6130 - loss: 1.0221 - val_accuracy: 0.6008 - val_loss: 1.0635
# Epoch 25/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.6054 - loss: 1.0409 - val_accuracy: 0.6107 - val_loss: 1.0507
# Epoch 26/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - accuracy: 0.6093 - loss: 1.0275 - val_accuracy: 0.6168 - val_loss: 1.0443
# Epoch 27/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 318s 1s/step - accuracy: 0.6157 - loss: 1.0258 - val_accuracy: 0.6013 - val_loss: 1.0520
# Epoch 28/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 543s 2s/step - accuracy: 0.6142 - loss: 1.0264 - val_accuracy: 0.6087 - val_loss: 1.0473
# Epoch 29/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 534s 2s/step - accuracy: 0.6200 - loss: 1.0074 - val_accuracy: 0.6102 - val_loss: 1.0580
# Epoch 30/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 534s 2s/step - accuracy: 0.6268 - loss: 0.9937 - val_accuracy: 0.6104 - val_loss: 1.0462
# Epoch 31/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 530s 2s/step - accuracy: 0.6255 - loss: 0.9883 - val_accuracy: 0.6163 - val_loss: 1.0420
# Epoch 32/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 529s 2s/step - accuracy: 0.6310 - loss: 0.9848 - val_accuracy: 0.6129 - val_loss: 1.0523
# Epoch 33/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 534s 2s/step - accuracy: 0.6244 - loss: 0.9956 - val_accuracy: 0.6110 - val_loss: 1.0502
# Epoch 34/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 530s 2s/step - accuracy: 0.6381 - loss: 0.9685 - val_accuracy: 0.6155 - val_loss: 1.0458
# Epoch 35/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 529s 2s/step - accuracy: 0.6251 - loss: 0.9737 - val_accuracy: 0.6197 - val_loss: 1.0378
# Epoch 36/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 530s 2s/step - accuracy: 0.6376 - loss: 0.9606 - val_accuracy: 0.6172 - val_loss: 1.0362
# Epoch 37/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 561s 2s/step - accuracy: 0.6383 - loss: 0.9671 - val_accuracy: 0.6145 - val_loss: 1.0321
# Epoch 38/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 534s 2s/step - accuracy: 0.6359 - loss: 0.9696 - val_accuracy: 0.6207 - val_loss: 1.0272
# Epoch 39/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 529s 2s/step - accuracy: 0.6439 - loss: 0.9533 - val_accuracy: 0.6156 - val_loss: 1.0358
# Epoch 40/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 530s 2s/step - accuracy: 0.6440 - loss: 0.9575 - val_accuracy: 0.6193 - val_loss: 1.0325
# Epoch 41/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 529s 2s/step - accuracy: 0.6476 - loss: 0.9413 - val_accuracy: 0.6169 - val_loss: 1.0337
# Epoch 42/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 567s 2s/step - accuracy: 0.6459 - loss: 0.9409 - val_accuracy: 0.6221 - val_loss: 1.0197
# Epoch 43/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 557s 2s/step - accuracy: 0.6505 - loss: 0.9354 - val_accuracy: 0.6230 - val_loss: 1.0230
# Epoch 44/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 567s 2s/step - accuracy: 0.6533 - loss: 0.9334 - val_accuracy: 0.6117 - val_loss: 1.0421
# Epoch 45/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 8350s 37s/step - accuracy: 0.6515 - loss: 0.9287 - val_accuracy: 0.6288 - val_loss: 1.0272
# Epoch 46/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 280s 1s/step - accuracy: 0.6580 - loss: 0.9141 - val_accuracy: 0.6224 - val_loss: 1.0296
# Epoch 47/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.6536 - loss: 0.9146 - val_accuracy: 0.6226 - val_loss: 1.0293
# Epoch 48/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.6642 - loss: 0.9104 - val_accuracy: 0.6237 - val_loss: 1.0284
# Epoch 49/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.6626 - loss: 0.9042 - val_accuracy: 0.6217 - val_loss: 1.0258
# Epoch 50/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - accuracy: 0.6682 - loss: 0.8874 - val_accuracy: 0.6274 - val_loss: 1.0185
# Epoch 51/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - accuracy: 0.6689 - loss: 0.8988 - val_accuracy: 0.6245 - val_loss: 1.0298
# Epoch 52/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 271s 1s/step - accuracy: 0.6635 - loss: 0.8981 - val_accuracy: 0.6237 - val_loss: 1.0301
# Epoch 53/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 320s 1s/step - accuracy: 0.6708 - loss: 0.8855 - val_accuracy: 0.6275 - val_loss: 1.0273
# Epoch 54/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.6701 - loss: 0.8727 - val_accuracy: 0.6245 - val_loss: 1.0285
# Epoch 55/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.6768 - loss: 0.8710 - val_accuracy: 0.6279 - val_loss: 1.0221
# Epoch 56/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 322s 1s/step - accuracy: 0.6741 - loss: 0.8744 - val_accuracy: 0.6207 - val_loss: 1.0278
# Epoch 57/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.6786 - loss: 0.8682 - val_accuracy: 0.6315 - val_loss: 1.0268
# Epoch 58/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - accuracy: 0.6827 - loss: 0.8571 - val_accuracy: 0.6301 - val_loss: 1.0260
# Epoch 59/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.6848 - loss: 0.8454 - val_accuracy: 0.6309 - val_loss: 1.0171
# Epoch 60/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.6844 - loss: 0.8470 - val_accuracy: 0.6288 - val_loss: 1.0277
# Epoch 61/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 322s 1s/step - accuracy: 0.6863 - loss: 0.8554 - val_accuracy: 0.6298 - val_loss: 1.0175
# Epoch 62/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 322s 1s/step - accuracy: 0.6896 - loss: 0.8476 - val_accuracy: 0.6325 - val_loss: 1.0237
# Epoch 63/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 268s 1s/step - accuracy: 0.6892 - loss: 0.8377 - val_accuracy: 0.6303 - val_loss: 1.0241
# Epoch 64/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.6920 - loss: 0.8342 - val_accuracy: 0.6243 - val_loss: 1.0377
# Epoch 65/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 348s 1s/step - accuracy: 0.6966 - loss: 0.8316 - val_accuracy: 0.6251 - val_loss: 1.0281
# Epoch 66/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.6887 - loss: 0.8358 - val_accuracy: 0.6271 - val_loss: 1.0361
# Epoch 67/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 468s 2s/step - accuracy: 0.6924 - loss: 0.8348 - val_accuracy: 0.6326 - val_loss: 1.0284
# Epoch 68/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 815s 4s/step - accuracy: 0.6954 - loss: 0.8175 - val_accuracy: 0.6360 - val_loss: 1.0228
# Epoch 69/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 896s 4s/step - accuracy: 0.7026 - loss: 0.8043 - val_accuracy: 0.6264 - val_loss: 1.0215
# Epoch 70/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 821s 4s/step - accuracy: 0.7024 - loss: 0.8068 - val_accuracy: 0.6219 - val_loss: 1.0452
# Epoch 71/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 822s 4s/step - accuracy: 0.6999 - loss: 0.8063 - val_accuracy: 0.6303 - val_loss: 1.0357
# Epoch 72/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 535s 2s/step - accuracy: 0.7035 - loss: 0.8135 - val_accuracy: 0.6261 - val_loss: 1.0377
# Epoch 73/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.7036 - loss: 0.8050 - val_accuracy: 0.6295 - val_loss: 1.0298
# Epoch 74/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 326s 1s/step - accuracy: 0.7042 - loss: 0.7957 - val_accuracy: 0.6344 - val_loss: 1.0290
# Epoch 75/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.7113 - loss: 0.7815 - val_accuracy: 0.6301 - val_loss: 1.0268
# Epoch 76/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 322s 1s/step - accuracy: 0.7152 - loss: 0.7767 - val_accuracy: 0.6271 - val_loss: 1.0310
# Epoch 77/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 322s 1s/step - accuracy: 0.7143 - loss: 0.7810 - val_accuracy: 0.6274 - val_loss: 1.0302
# Epoch 78/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 323s 1s/step - accuracy: 0.7105 - loss: 0.7922 - val_accuracy: 0.6332 - val_loss: 1.0170
# Epoch 79/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.7137 - loss: 0.7773 - val_accuracy: 0.6261 - val_loss: 1.0224
# Epoch 80/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.7194 - loss: 0.7699 - val_accuracy: 0.6240 - val_loss: 1.0345
# Epoch 81/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.7153 - loss: 0.7760 - val_accuracy: 0.6302 - val_loss: 1.0160
# Epoch 82/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.7185 - loss: 0.7719 - val_accuracy: 0.6302 - val_loss: 1.0312
# Epoch 83/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.7216 - loss: 0.7609 - val_accuracy: 0.6303 - val_loss: 1.0348
# Epoch 84/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.7239 - loss: 0.7440 - val_accuracy: 0.6262 - val_loss: 1.0271
# Epoch 85/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.7242 - loss: 0.7606 - val_accuracy: 0.6325 - val_loss: 1.0332
# Epoch 86/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 322s 1s/step - accuracy: 0.7255 - loss: 0.7540 - val_accuracy: 0.6332 - val_loss: 1.0322
# Epoch 87/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.7310 - loss: 0.7392 - val_accuracy: 0.6292 - val_loss: 1.0537
# Epoch 88/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 722s 3s/step - accuracy: 0.7319 - loss: 0.7325 - val_accuracy: 0.6277 - val_loss: 1.0351
# Epoch 89/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 846s 4s/step - accuracy: 0.7264 - loss: 0.7486 - val_accuracy: 0.6366 - val_loss: 1.0325
# Epoch 90/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 848s 4s/step - accuracy: 0.7333 - loss: 0.7306 - val_accuracy: 0.6320 - val_loss: 1.0354
# Epoch 91/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 838s 4s/step - accuracy: 0.7330 - loss: 0.7373 - val_accuracy: 0.6299 - val_loss: 1.0467
# Epoch 92/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 860s 4s/step - accuracy: 0.7381 - loss: 0.7281 - val_accuracy: 0.6322 - val_loss: 1.0272
# Epoch 93/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 824s 4s/step - accuracy: 0.7347 - loss: 0.7327 - val_accuracy: 0.6267 - val_loss: 1.0603
# Epoch 94/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 863s 4s/step - accuracy: 0.7327 - loss: 0.7290 - val_accuracy: 0.6315 - val_loss: 1.0371
# Epoch 95/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 862s 4s/step - accuracy: 0.7370 - loss: 0.7163 - val_accuracy: 0.6308 - val_loss: 1.0392
# Epoch 96/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 743s 3s/step - accuracy: 0.7307 - loss: 0.7352 - val_accuracy: 0.6295 - val_loss: 1.0469
# Epoch 97/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - accuracy: 0.7351 - loss: 0.7251 - val_accuracy: 0.6357 - val_loss: 1.0408
# Epoch 98/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - accuracy: 0.7417 - loss: 0.7182 - val_accuracy: 0.6271 - val_loss: 1.0550
# Epoch 99/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 322s 1s/step - accuracy: 0.7417 - loss: 0.7054 - val_accuracy: 0.6235 - val_loss: 1.0566
# Epoch 100/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 275s 1s/step - accuracy: 0.7467 - loss: 0.6979 - val_accuracy: 0.6288 - val_loss: 1.0517

# %%
model_json = model.to_json()
with open("emotiondetector.json",'w') as json_file:
    json_file.write(model_json)
model.save("emotiondetector.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
label = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
def ef(image):
    img = load_img(image, grayscale = True)
    feature = np.array(img)
    feature = feature.reshape(1,48,48)
    return feature/255.0

# %%
image = 'images/train/sad/42.jpg'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is: ",pred_label)
# Out:
# original image is of sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# model prediction is:  sad

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = 'images/train/fear/2.jpg'
print("original image is of fear")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ", pred_label)
plt.imshow(img.reshape(48,48), cmap = 'gray')
# Out:
# original image is of fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# model prediction is  fear
# C:\Users\Anshimsa\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_preprocessing\image\utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
